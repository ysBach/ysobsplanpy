# %%
# %config InlineBackend.figure_format = 'retina'
from matplotlib import pyplot as plt
from matplotlib import rcParams
import ysobsplanpy as op

# %%
# We need to do it in a separate cell. See:
# https://github.com/jupyter/notebook/issues/3385
plt.style.use('default')
rcParams.update({'font.size':12})

# %%
pos = dict(
    ceres1=dict(ra="22:25:01.46", dec="-25:11:41.2"),
    ceres2=dict(ra="22:25:11.30", dec="-24:34:44.3"),
#     ceres2=dict(ra="22:25:11.30", dec="-24:54:44.3"),
    pallas1=dict(ra="18:56:42.74", dec="+05:06:22.8"),
#     pallas2=dict(ra="20:06:42.28", dec="-00:27:19.8"),
    suhyun=dict(ra="01:17:33", dec="-04:44:44"),
)

fig, axs = plt.subplots(2, 2, figsize=(12, 12), 
                        sharex=False, sharey=False, gridspec_kw=None)

for i, (name, v) in enumerate(pos.items()):
    if i < 3:
        continue
    ax = axs.flatten()[i]
    gs = op.GuideStars(ra=v['ra'], dec=v['dec'], radius=1/60)
    gs.query(mag_cut=22)
    gs.quickplot(ax, size_factor=3, num_show_mag=10)
    ax.set_title(name)
    

plt.tight_layout()
fig.align_ylabels(axs)
fig.align_xlabels(axs)
plt.show()


# plt.savefig(figoutpath, dpi=300, bbox_inches = "tight")
# Out:
# FoV = (0.0, 0.0) arcmin

# %%
gs.queried.to_pandas()
# Out:
#              objID           gsc2ID         gsc1ID          hstID        ra  \
# 0       2000032043    b'S000032043'  b'0466600734'  b'S01K000043'  1.046228
# 1       2000032046    b'S000032046'  b'0466600902'  b'S01K000046'  1.261102
# 2       2000001030    b'S000001030'  b'0466600702'  b'S004000030'  1.084240
# 3       2000032342    b'S000032342'  b'0466600476'  b'S01N000042'  1.530276
# 4       2000032026    b'S000032026'  b'0466600602'  b'S01K000026'  1.267261
# ...            ...              ...            ...            ...       ...
# 2561  200003232722  b'S00003232722'            b''  b'S01N002722'  1.719504
# 2562  200003204981  b'S00003204981'            b''  b'S01K004981'  1.175458
# 2563  200003231346  b'S00003231346'            b''  b'S01N001346'  1.689144
# 2564  200003204957  b'S00003204957'            b''  b'S01K004957'  1.140588
# 2565  200003204058  b'S00003204058'            b''  b'S01K004058'  0.902628
#
#            dec        epoch  raEpsilon  decEpsilon       rapm  ...  \
# 0    -4.926106  2000.000000   0.010000     0.01500  23.799999  ...
# 1    -4.971255  2000.000000   0.016000     0.02300  32.599998  ...
# 2    -4.411378  2000.000000   0.020000     0.02600  83.599998  ...
# 3    -4.516306  2000.000000   0.032000     0.03000   3.700000  ...
# 4    -4.807435  2000.000000   0.032000     0.04400  11.400000  ...
# ...        ...          ...        ...         ...        ...  ...
# 2561 -4.658724  1989.890015   0.389063     0.38511   0.000000  ...
# 2562 -4.675284  1989.890015   0.389063     0.38511  -8.893650  ...
# 2563 -4.960787  1989.890015   0.389063     0.38511 -12.484500  ...
# 2564 -4.687533  1989.890015   0.389063     0.38511   0.000000  ...
# 2565 -4.965683  1989.890015   0.389063     0.38511 -32.276699  ...
#
#       eccentricity  positionAngle  sourceStatus  variableFlag  multipleFlag  \
# 0         0.000000       0.000000      99999900             0             0
# 1         0.000000       0.000000      99999900             0             0
# 2         0.000000       0.000000      99999900             0             0
# 3         0.000000       0.000000      99999900             0             0
# 4         0.000000       0.000000      99999900             0             0
# ...            ...            ...           ...           ...           ...
# 2561      0.319610      32.213402      10010201             0             0
# 2562      0.360319      31.067301         12204             0             0
# 2563      0.260801      33.132599       1010202             0             0
# 2564      0.228919     146.365997      10010201             0             0
# 2565      0.247287      41.004398         10202             0             0
#
#       compassGSC2id        Mag        _r  offset_x  offset_y
# 0     3282400000043   9.642000  0.304659 -0.245363 -0.180594
# 1     3282400000046  10.208000  0.227858 -0.031280 -0.225700
# 2     3277200000030  10.400000  0.393409 -0.207647  0.334146
# 3     3282700000042  10.554000  0.329733  0.237039  0.229209
# 4     3282400000026  10.704000  0.066795 -0.025150 -0.061879
# ...             ...        ...       ...       ...       ...
# 2561  3282700002722  19.995100  0.434335  0.425594  0.086700
# 2562  3282400004981  19.995100  0.136178 -0.116653  0.070261
# 2563  3282700001346  19.995199  0.450028  0.395161 -0.215344
# 2564  3282400004957  19.999100  0.162136 -0.151404  0.058006
# 2565  3282400004058  19.999901  0.446505 -0.388411 -0.220236
#
# [2566 rows x 59 columns]
